# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text)
#print(soup.prettify())

# %%
d =soup.find(class_="r-ent")
   
    
print('標題：',d.find(class_='title').text.replace('\t', '').replace('\n', ''))
print('作者：',d.find(class_='author').text)
print('時間：',d.find(class_='date').text)
# Out:
# 標題： [BOX ] Raptors 108:116 Heat 數據
# 作者： Rambo
# 時間：  2/25

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
for d in soup.find_all(class_="r-ent"):
   
    
    print('標題：',d.find(class_='title').text.replace('\t', '').replace('\n', ''))
    print('作者：',d.find(class_='author').text)
    print('時間：',d.find(class_='date').text)
    print('\n')
# Out:
# 標題： [BOX ] Raptors 108:116 Heat 數據
# 作者： Rambo
# 時間：  2/25
#
#
# 標題： [情報] SGA成為OKC史上第三年輕得到40分以上
# 作者： kevinwei223
# 時間：  2/25
#
#
# 標題： (已被namie810303刪除) <TYisBRoKen>1-1
# 作者： -
# 時間：  2/25
#
#
# 標題： [情報] 輸給騎士後，火箭三分命中率墊底
# 作者： ejijo761115
# 時間：  2/25
#
#
# 標題： [外絮] 賽提老闆：Kyrie的離開改變了很多事情
# 作者： mingonly
# 時間：  2/25
#
#
# 標題： [討論]為什麼湖人戰力排名跟賭盤都贏快艇?
# 作者： a000703
# 時間：  2/25
#
#
# 標題： [BOX ] Hornets 124:121 Suns 數據
# 作者： Rambo
# 時間：  2/25
#
#
# 標題： (本文已被刪除) [t200830217]
# 作者： -
# 時間：  2/25
#
#
# 標題： [新聞] 戰鬥陀螺　威廉森禁區大轉身！4人包夾守
# 作者： soujaw
# 時間：  2/25
#
#
# 標題： [BOX ] Lakers 89:114 Jazz 數據
# 作者： Rambo
# 時間：  2/25
#
#
# 標題： [情報] LBJ最近9場比賽 三分只有19.6%的命中率
# 作者： VeryGoodBoy
# 時間：  2/25
#
#
# 標題： [新聞] 爵士三分砲火轟垮防線 湖人近6戰苦吞5敗
# 作者： bbbyes123
# 時間：  2/25
#
#
# 標題： [討論] LeBron James 的帶隊能力是不是很糟糕？
# 作者： KobebeatMJ
# 時間：  2/25
#
#
# 標題： Re: [討論] LeBron James 的帶隊能力是不是很糟糕？
# 作者： TheoEpstein
# 時間：  2/25
#
#
# 標題： [討論] AD影響力有那麼大嗎
# 作者： ghost069
# 時間：  2/25
#
#
# 標題： [專欄] 明星賽入選球員討論_以BPM進階數據切入
# 作者： wxyzz0525
# 時間：  2/25
#
#
# 標題： [花邊] 參加灌籃大賽？　Zion：誰知道
# 作者： thnlkj0665
# 時間：  2/25
#
#
# 標題： [情報] NBA Standings (Feb. 25, 2021)
# 作者： guardyo
# 時間：  2/25
#
#
# 標題： [花邊]Ingram：從未與我相同天賦的球員打過球
# 作者： mingonly
# 時間：  2/25
#
#
# 標題： [新聞] 湖人攻守狀態低迷 詹姆斯:球隊處境有些艱難
# 作者： thnlkj0665
# 時間：  2/25
#
#
# 標題： [公告] 板規v6.8
# 作者： Vedan
# 時間：  5/24
#
#
# 標題： [情報] 2020-21 自由球員市場異動 (表格)(12/10)
# 作者： laigei
# 時間： 11/19
#
#
# 標題： [情報] 2020-21 自由球員市場異動 (每日文字)
# 作者： laigei
# 時間： 11/19
#
#
# 標題： [情報] SEASON Schedule 賽程 February 20–21
# 作者： laptic
# 時間：  1/29

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''
#PTT八卦版
url2 = 'https://www.ptt.cc/bbs/Gossiping/index.html'
#八卦版須加cookies
r1 = requests.get(url2,cookies={'over18':'1'})
soup1 = BeautifulSoup(r1.text)
#print(soup1.prettify())

# %%
for d in soup1.find_all(class_="r-ent"):
   
    print('標題：',d.find(class_='title').text.replace('\t', '').replace('\n', ''))
    print('作者：',d.find(class_='author').text)
    print('時間：',d.find(class_='date').text)
    print('\n')
# Out:
# 標題： [問卦] 公投是一個很危險的工具！
# 作者： Anderson0819
# 時間：  2/25
#
#
# 標題： [問卦] 麻古飲料店都什麼人在喝
# 作者： y303y191
# 時間：  2/25
#
#
# 標題： Re: [問卦] 藻礁公投差22萬份，應該放棄了吧？
# 作者： wolver
# 時間：  2/25
#
#
# 標題： Re: [問卦] 舊大樓電梯，最近消防檢查，需要加貼無障
# 作者： mikemagic88
# 時間：  2/25
#
#
# 標題： Re: [新聞] 中國侵害人權 英國籲聯合國調查 中方：歡
# 作者： DANANPA
# 時間：  2/25
#
#
# 標題： [問卦] 『黎明』在電影上有代表作嗎?
# 作者： mnhyuiop
# 時間：  2/25
#
#
# 標題： [問卦] 手搖店是不是太多了= =
# 作者： seabox
# 時間：  2/25
#
#
# 標題： Re: [問卦] 人生online 修改器要怎用？
# 作者： xzcb2008
# 時間：  2/25
#
#
# 標題： Re: [新聞] 台灣不能重演228！蔡英文掛保證：原住民觀點不再受忽略
# 作者： butten986
# 時間：  2/25
#
#
# 標題： [問卦] 胡瓜跟阿信為什麼那麼像？
# 作者： yasionl
# 時間：  2/25
#
#
# 標題： Re: [新聞] 「台大宅王」當街47刀殺女友　痛哭認錯
# 作者： greenseason
# 時間：  2/25
#
#
# 標題： [問卦] 台灣缺電是不是高科技業害的？
# 作者： kinki999
# 時間：  2/25
#
#
# 標題： [問卦] 外送師的評價標準怎麼給?
# 作者： VB6
# 時間：  2/25
#
#
# 標題： [公告] 八卦板板規(2020.11.21)
# 作者： arsonlolita
# 時間： 11/21
#
#
# 標題： [協尋] 2/14早上九點到10點鳳山鳳林路車禍影像
# 作者： mo0219
# 時間：  2/14
#
#
# 標題： [協尋] 2/19 國道3號新竹89公里車禍影像
# 作者： yiwin23
# 時間：  2/20
#
#
# 標題： [公告] 歌唱大賽置底投票 本篇推文投票
# 作者： arsonlolita
# 時間：  2/22
#
#
# 標題： [協尋] 02/15/08:00~10:00首都客運-電子耳遺失
# 作者： alittlekoa
# 時間：  2/16
